# %%
import pandas as pd
a=pd.read_csv("AllPair.csv")
print(len(set(list(a["TF"]))))
print(len(set(list(a["Target"]))))
b=list(set(list(a["TF"])+(list(a["Target"]))))
print(len(b))
p="/home/featurize/work/cs-main/reproduce/scMGF-GRNS/dataset/scRNA-Seq/STRING_Dataset/mHSC-L/TFs+500/raw/mouse/gene_list.txt"
b= [a.title() for a in b]
with open(p, "w") as f:
    f.write("\n".join(b))
# Out:
# 499
# 785
# 799
