# %%
import pandas as pd
a=pd.read_csv("BL--ExpressionData.csv").T
print(a)
a.to_csv("network.csv",index=False)
# Out:
#                 0         1         2         3         4         5     \
# Unnamed: 0    TM7SF3   CHCHD10      CST7   SLC26A2     PSMD9     STT3A
# HSPC_025         0.0  2.599758   2.12914  1.426148  2.599758  9.145269
# HSPC_031    1.168027  7.393207  0.699126  0.699126  1.168027  5.539687
# LT_HSC_001       0.0  4.694167  2.579528  9.306369   5.51718  8.428123
# HSPC_001      1.4789  8.020816  1.226829       0.0  0.532906  8.985339
# ...              ...       ...       ...       ...       ...       ...
# Prog_809    6.603892  5.846099  6.108645  0.527667  6.816647  8.899302
# Prog_834     8.32618  4.598461  7.674846   4.21239  6.103935   5.07491
# Prog_840    7.617621  6.109641  8.636546  5.672679  6.723257  7.712873
# Prog_846    7.706202  6.930717  8.940751  5.136037  6.683429  8.739244
# Prog_810    7.162547  0.760415  9.342464  7.758091  5.775664  9.395458
#
#                 6         7         8         9     ...      1122      1123  \
# ...
